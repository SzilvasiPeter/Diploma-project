# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
student_data = pd.read_csv('../../datasets/student-mat.csv')

# %%
student_data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other ...
# 3     GP   F   15       U     GT3       T     4     2   health  services ...
# 4     GP   F   16       U     GT3       T     3     3    other     other ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
student_data['G1'].describe()
# Out:
# count    395.000000
# mean      10.908861
# std        3.319195
# min        3.000000
# 25%        8.000000
# 50%       11.000000
# 75%       13.000000
# max       19.000000
# Name: G1, dtype: float64

# %%
categories = ['First Period', 'Second Period', 'Final']
student_score = [student_data['G1'].head(5),
                 student_data['G2'].head(5),
                 student_data['G3'].head(5)]

plt.plot(categories, student_score)
plt.title('Score Line Chart')
plt.xlabel('Periods')
plt.ylabel('Scores')
plt.show()

# %%
student_df = pd.read_csv('../../datasets/student_mat_processed01.csv')

# %%
student_df.head(10)
# Out:
#    sex  age  address  famsize  Medu  Fedu  traveltime  studytime  failures  \
# 0    0   18        1        0     4     4           2          2         0
# 1    0   17        1        0     1     1           1          2         0
# 2    0   15        1        1     1     1           1          2         3
# 3    0   15        1        0     4     2           1          3         0
# 4    0   16        1        0     3     3           1          2         0
# 5    1   16        1        1     4     3           1          2         0
# 6    1   16        1        1     2     2           1          2         0
# 7    0   17        1        0     4     4           2          2         0
# 8    1   15        1        1     3     2           1          2         0
# 9    1   15        1        0     3     4           1          2         0
#
#    schoolsup       ...        Fjob_other  Fjob_services  Fjob_teacher  \
# 0          1       ...                 0              0             1
# ...

# %%
student_df['G3'].describe()
# Out:
# count    395.000000
# mean      10.415190
# std        4.581443
# min        0.000000
# 25%        8.000000
# 50%       11.000000
# 75%       14.000000
# max       20.000000
# Name: G3, dtype: float64

# %%
corrmat = student_df.corr()
print(corrmat)
# Out:
#                         sex       age   address   famsize      Medu      Fedu  \
# sex                1.000000 -0.028606 -0.028504  0.089862  0.078228  0.034878
# age               -0.028606  1.000000 -0.146722  0.037847 -0.163658 -0.163438
# address           -0.028504 -0.146722  1.000000  0.072472  0.138804  0.072178
# famsize            0.089862  0.037847  0.072472  1.000000 -0.043068 -0.058879
# Medu               0.078228 -0.163658  0.138804 -0.043068  1.000000  0.623455
# Fedu               0.034878 -0.163438  0.072178 -0.058879  0.623455  1.000000
# traveltime         0.059722  0.070641 -0.328096  0.063493 -0.171639 -0.158194
# studytime         -0.306268 -0.004140 -0.020912 -0.073595  0.064944 -0.009175
# failures           0.044436  0.243665 -0.078578 -0.015769 -0.236680 -0.250408
# schoolsup         -0.138271 -0.251811  0.024712 -0.028642 -0.036029  0.037530
# famsup            -0.151623 -0.140609  0.023903 -0.112893  0.183727  0.185496
# ...

# %%
plt.figure(figsize=(25,25))
sb.heatmap(corrmat, square=False, annot=True,cmap="YlGnBu");

# %%
sb.regplot(x="G3", y="failures", data=student_df)

# %%
sb.regplot(x="goout", y="freetime", data=student_df)

# %%
sb.distplot(student_df['G3'])
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sb.boxplot(y=student_df['freetime'])
